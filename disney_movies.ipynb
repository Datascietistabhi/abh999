# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sn

# %%
df=pd.read_csv("a.csv")
df
# Out:
#                          movie_title release_date      genre mpaa_rating  \
# 0    Snow White and the Seven Dwarfs   1937-12-21    Musical           G
# 1                          Pinocchio   1940-02-09  Adventure           G
# 2                           Fantasia   1940-11-13    Musical           G
# 3                  Song of the South   1946-11-12  Adventure           G
# 4                         Cinderella   1950-02-15      Drama           G
# ..                               ...          ...        ...         ...
# 574         The Light Between Oceans   2016-09-02      Drama       PG-13
# 575                   Queen of Katwe   2016-09-23      Drama          PG
# 576                   Doctor Strange   2016-11-04  Adventure       PG-13
# 577                            Moana   2016-11-23  Adventure          PG
# 578     Rogue One: A Star Wars Story   2016-12-16  Adventure       PG-13
#
#      total_gross  inflation_adjusted_gross
# 0      184925485                5228953251
# ...

# %%
df.head()
# Out:
#                        movie_title release_date      genre mpaa_rating  \
# 0  Snow White and the Seven Dwarfs   1937-12-21    Musical           G
# 1                        Pinocchio   1940-02-09  Adventure           G
# 2                         Fantasia   1940-11-13    Musical           G
# 3                Song of the South   1946-11-12  Adventure           G
# 4                       Cinderella   1950-02-15      Drama           G
#
#    total_gross  inflation_adjusted_gross
# 0    184925485                5228953251
# 1     84300000                2188229052
# 2     83320000                2187090808
# 3     65000000                1078510579
# 4     85000000                 920608730

# %%
df.tail()
# Out:
#                       movie_title release_date      genre mpaa_rating  \
# 574      The Light Between Oceans   2016-09-02      Drama       PG-13
# 575                Queen of Katwe   2016-09-23      Drama          PG
# 576                Doctor Strange   2016-11-04  Adventure       PG-13
# 577                         Moana   2016-11-23  Adventure          PG
# 578  Rogue One: A Star Wars Story   2016-12-16  Adventure       PG-13
#
#      total_gross  inflation_adjusted_gross
# 574     12545979                  12545979
# 575      8874389                   8874389
# 576    232532923                 232532923
# 577    246082029                 246082029
# 578    529483936                 529483936

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 579 entries, 0 to 578
# Data columns (total 6 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   movie_title               579 non-null    object
#  1   release_date              579 non-null    object
#  2   genre                     562 non-null    object
#  3   mpaa_rating               523 non-null    object
#  4   total_gross               579 non-null    int64
#  5   inflation_adjusted_gross  579 non-null    int64
# dtypes: int64(2), object(4)
# memory usage: 18.2+ KB

# %%
df.isnull().sum()
# Out:
# movie_title                  0
# release_date                 0
# genre                       17
# mpaa_rating                 56
# total_gross                  0
# inflation_adjusted_gross     0
# dtype: int64

# %%
df.fillna(np.NaN,inplace=True)

# %%
df['release_date'] = pd.to_datetime(df['release_date'])

# %%
df['year'] = df['release_date'].dt.date.astype(str).str.split('-', expand=True)[0]

# %%
df.head()
# Out:
#                        movie_title release_date      genre mpaa_rating  \
# 0  Snow White and the Seven Dwarfs   1937-12-21    Musical           G
# 1                        Pinocchio   1940-02-09  Adventure           G
# 2                         Fantasia   1940-11-13    Musical           G
# 3                Song of the South   1946-11-12  Adventure           G
# 4                       Cinderella   1950-02-15      Drama           G
#
#    total_gross  inflation_adjusted_gross  year
# 0    184925485                5228953251  1937
# 1     84300000                2188229052  1940
# 2     83320000                2187090808  1940
# 3     65000000                1078510579  1946
# 4     85000000                 920608730  1950

# %%
df.sort_values('total_gross',ascending=False).head(5)
# Out:
#                               movie_title release_date      genre mpaa_rating  \
# 564  Star Wars Ep. VII: The Force Awakens   2015-12-18  Adventure       PG-13
# 524                          The Avengers   2012-05-04     Action       PG-13
# 578          Rogue One: A Star Wars Story   2016-12-16  Adventure       PG-13
# 571                          Finding Dory   2016-06-17  Adventure          PG
# 558               Avengers: Age of Ultron   2015-05-01     Action       PG-13
#
#      total_gross  inflation_adjusted_gross  year
# 564    936662225                 936662225  2015
# 524    623279547                 660081224  2012
# 578    529483936                 529483936  2016
# 571    486295561                 486295561  2016
# 558    459005868                 459005868  2015

# %%
df.sort_values('inflation_adjusted_gross',ascending=False).head(5)
# Out:
#                        movie_title release_date      genre mpaa_rating  \
# 0  Snow White and the Seven Dwarfs   1937-12-21    Musical           G
# 1                        Pinocchio   1940-02-09  Adventure           G
# 2                         Fantasia   1940-11-13    Musical           G
# 8                   101 Dalmatians   1961-01-25     Comedy           G
# 6               Lady and the Tramp   1955-06-22      Drama           G
#
#    total_gross  inflation_adjusted_gross  year
# 0    184925485                5228953251  1937
# 1     84300000                2188229052  1940
# 2     83320000                2187090808  1940
# 8    153000000                1362870985  1961
# 6     93600000                1236035515  1955

# %%
plt.style.use('dark_background')

# %%
sn.countplot(y='genre',data=df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='genre'>

# %%
plt.figure(figsize=(12,8))
plt.xticks(rotation=90)
sn.histplot(df['year'],kde=True)
# Out:
# <AxesSubplot:xlabel='year', ylabel='Count'>

# %%
plt.figure(figsize=(12,8))
plt.xticks(rotation=90)
sn.histplot(x='year',hue='genre',data=df)
# Out:
# <AxesSubplot:xlabel='year', ylabel='Count'>

# %%
sn.barplot(y='genre',x='total_gross',data=df)
# Out:
# <AxesSubplot:xlabel='total_gross', ylabel='genre'>

# %%
plt.figure(figsize=(12,6))
sn.boxplot(y='genre',x='inflation_adjusted_gross',data=df)
# Out:
# <AxesSubplot:xlabel='inflation_adjusted_gross', ylabel='genre'>

# %%
sn.countplot(x='mpaa_rating',data=df)
# Out:
# <AxesSubplot:xlabel='mpaa_rating', ylabel='count'>

# %%
plt.figure(figsize=(12,8))
plt.xticks(rotation=90)
sn.lineplot(x='year', y='inflation_adjusted_gross', data=df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-dff2b11d53c8> in <module>
#       1 plt.figure(figsize=(12,8))
#       2 plt.xticks(rotation=90)
# ----> 3 sn.lineplot(x='year', y='inflation_adjusted_gross', data=df)
#
# ~\Anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\Anaconda3\lib\site-packages\seaborn\relational.py in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend, ax, **kwargs)
#     676
#     677     variables = _LinePlotter.get_semantics(locals())
# --> 678     p = _LinePlotter(
# ...

# %%
plt.figure(figsize=(12,8))
plt.xticks(rotation=90)
sn.lineplot(x='year', y='total_gross', data=df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-197bb3f45685> in <module>
#       1 plt.figure(figsize=(12,8))
#       2 plt.xticks(rotation=90)
# ----> 3 sn.lineplot(x='year', y='total_gross', data=df)
#
# ~\Anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\Anaconda3\lib\site-packages\seaborn\relational.py in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend, ax, **kwargs)
#     676
#     677     variables = _LinePlotter.get_semantics(locals())
# --> 678     p = _LinePlotter(
# ...

# %%
plt.figure(figsize=(8,4))
sn.countplot(x='mpaa_rating',hue='genre',data=df)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
sn.lmplot(x='total_gross',y='inflation_adjusted_gross',data=df)

# %%
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import cufflinks as cf
init_notebook_mode(connected=True)
cf.go_offline()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-40-20a1659b30db> in <module>
# ----> 1 from plotly import __version__
#       2 from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
#       3 import cufflinks as cf
#       4 init_notebook_mode(connected=True)
#       5 cf.go_offline()
#
# ModuleNotFoundError: No module named 'plotly'
